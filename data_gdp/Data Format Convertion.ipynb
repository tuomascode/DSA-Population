# %%
import pandas as pd

# Load Excel file
file_path = "GDP.csv"
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#                   Country Name Country Code        1960        1961  \
# 0                        Aruba          ABW         NaN         NaN
# 1  Africa Eastern and Southern          AFE  186.121835  186.941781
# 2                  Afghanistan          AFG         NaN         NaN
# 3   Africa Western and Central          AFW  121.939925  127.454189
# 4                       Angola          AGO         NaN         NaN
#
#          1962        1963        1964        1965        1966        1967  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1  197.402402  225.440494  208.999748  226.876513  240.955232  243.817323
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3  133.827044  139.008291  148.549379  155.565216  162.110768  144.943480
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    ...          2015          2016          2017          2018          2019  \
# ...

# %%
print(df.columns)
# Out:
# Index(['Country Name', 'Country Code', '1960', '1961', '1962', '1963', '1964',
#        '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973',
#        '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982',
#        '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991',
#        '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000',
#        '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019', '2020', '2021', '2022', '2023', '2024'],
#       dtype='object')

# %%
# 1. Melt the DataFrame to transform it from wide to long format
df_long = pd.melt(df, 
                  id_vars=['Country Name', 'Country Code'], 
                  var_name='Time', 
                  value_name='GDP')

# %%
# 2. Rename columns to match your desired output
df_long = df_long.rename(columns={'Country Code': 'ISO2_code'})
df.loc[df["Country Name"] == "Namibia", "ISO2_code"] = "NA"

# %%
# 3. Sort the DataFrame by country and then by year
df_long = df_long.sort_values(by=['ISO2_code', 'Time'])

# %%
# 4. (Optional) Remove the 'Country Name' if you don't need it
# df_long = df_long.drop(columns=['Country Name'])

# %%
# 5. (Optional) Reset the index
df_long = df_long.reset_index(drop=True)

# Display the first 10 rows of the transformed data
print(df_long.head(50))
# Out:
#    Country Name ISO2_code  Time           GDP
# 0         Aruba       ABW  1960           NaN
# 1         Aruba       ABW  1961           NaN
# 2         Aruba       ABW  1962           NaN
# 3         Aruba       ABW  1963           NaN
# 4         Aruba       ABW  1964           NaN
# 5         Aruba       ABW  1965           NaN
# 6         Aruba       ABW  1966           NaN
# 7         Aruba       ABW  1967           NaN
# 8         Aruba       ABW  1968           NaN
# 9         Aruba       ABW  1969           NaN
# 10        Aruba       ABW  1970           NaN
# 11        Aruba       ABW  1971           NaN
# 12        Aruba       ABW  1972           NaN
# 13        Aruba       ABW  1973           NaN
# 14        Aruba       ABW  1974           NaN
# 15        Aruba       ABW  1975           NaN
# 16        Aruba       ABW  1976           NaN
# 17        Aruba       ABW  1977           NaN
# 18        Aruba       ABW  1978           NaN
# ...

# %%
df_long.shape
# Out:
# (17290, 4)

# %%
# Save the DataFrame to a CSV file
df_long.to_csv('gdp_data.csv', index=False)
