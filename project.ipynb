# %%
### Database related code ###

# %%
import pandas as pd

# data = pd.read_csv("WB_WDI_SP_DYN_LE00_IN_WIDEF.csv")
data = pd.read_excel("WPP2024_GEN_F01_DEMOGRAPHIC_INDICATORS_COMPACT.xlsx")
data.describe()
# Out:
#        Unnamed: 0 Unnamed: 1                       Unnamed: 2  Unnamed: 3  \
# count       21984      21984                            21984        5629
# unique      21984          2                              301          48
# top         Index  Estimates  Latin America and the Caribbean           2
# freq            1      21983                              148         814
#
#         Unnamed: 4 Unnamed: 5 Unnamed: 6  Unnamed: 7    Unnamed: 8  \
# count        21993      17539      17465       20943         21984
# unique         312        238        237         282            10
# top            876        BDI         BI         419  Country/Area
# freq            74         74         74         148         17538
#
#         Unnamed: 9  ...  Unnamed: 55 Unnamed: 56 Unnamed: 57  Unnamed: 58  \
# count        21984  ...        21984       21984       21984        21984
# unique          38  ...        21420       21364       20924        20865
# ...
